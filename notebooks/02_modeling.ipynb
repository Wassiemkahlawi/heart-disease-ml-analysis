# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

df = pd.read_csv(r"C:\Projects\heart-disease-ml-analysis\data\raw\heart_clean.csv")

# %%
df.shape
# Out:
# (302, 14)
